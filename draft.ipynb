# %%
lfw_mask = r'lfw_mask_100'
dst_path= r'user_face\mask'

# %%
import os
import shutil

# %%
ls_user = os.listdir(lfw_mask)
count = 0
for user in ls_user:
    ls_img = os.listdir(os.path.join(lfw_mask, user))
    if len(ls_img) > 5:
        if not os.path.exists(os.path.join(dst_path, user)):
            os.mkdir(os.path.join(dst_path, user))
            
        for img in ls_img[:5]:
            src = os.path.join(os.path.join(lfw_mask, user), img)
            dst = os.path.join(os.path.join(dst_path, user), img)
            shutil.move(src, dst)

        count += 1
    
    if count == 100:
        break

# %%
with open('data_embeddings.csv', 'r') as f:
    lines = f.readlines

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data_embeddings.csv')
df
# Out:
#                                        Name  \
# 0              Aaron_Peirsol_0002_cloth.jpg
# 1               Aaron_Peirsol_0002_KN95.jpg
# 2                Aaron_Peirsol_0002_N95.jpg
# 3      Aaron_Peirsol_0002_surgical_blue.jpg
# 4     Aaron_Peirsol_0002_surgical_green.jpg
# ...                                     ...
# 1984             Ann_Veneman_0011_cloth.jpg
# 1985              Ann_Veneman_0011_KN95.jpg
# 1986               Ann_Veneman_0011_N95.jpg
# 1987     Ann_Veneman_0011_surgical_blue.jpg
# 1988    Ann_Veneman_0011_surgical_green.jpg
#
#                                               Embedding   Ground_truth
# 0     tensor([[ 2.6792e-02,  3.3617e-02,  1.4725e-01...  Aaron_Peirsol
# 1     tensor([[ 1.9651e-02,  3.5368e-02,  1.4815e-01...  Aaron_Peirsol
# 2     tensor([[ 1.7728e-02,  3.9754e-02,  1.5794e-01...  Aaron_Peirsol
# 3     tensor([[ 2.8484e-02,  1.9044e-02,  1.5884e-01...  Aaron_Peirsol
# 4     tensor([[ 2.7511e-02,  1.3973e-02,  1.6530e-01...  Aaron_Peirsol
# ...

# %%
ground_truth = df['Ground_truth']
embeds = df['Embedding']
np.array(ground_truth)
# Out:
# array(['Aaron_Peirsol', 'Aaron_Peirsol', 'Aaron_Peirsol', ...,
#        'Ann_Veneman', 'Ann_Veneman', 'Ann_Veneman'], dtype=object)

# %%
for i in range(len(embeds)):
    print(type(embeds[i]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
import torch
ground_truth = np.load(r'database\data_names.npy')
mask_embeds = torch.load(r'database\data_embeddings.pth')

# %%
len(ground_truth)
# Out:
# 1989

# %%
mask_embeds[0].flatten()
# Out:
# tensor([ 2.6792e-02,  3.3617e-02,  1.4725e-01, -1.5171e-02,  5.6589e-03,
#         -1.0969e-02,  4.9773e-02, -7.4862e-03,  2.9846e-02,  2.0070e-02,
#         -2.8174e-02, -2.0617e-03, -3.1431e-02, -3.3731e-02, -9.0442e-02,
#         -5.2326e-02, -3.1600e-02, -4.1278e-02, -6.2558e-03, -1.0268e-01,
#         -2.7614e-02, -1.5916e-02, -1.1367e-02, -1.3024e-02, -3.3174e-02,
#         -3.2741e-03,  1.1079e-02,  3.6159e-02, -3.1193e-02,  6.7784e-02,
#         -6.4892e-02,  1.9421e-02,  3.1898e-03,  3.7802e-02,  1.7663e-02,
#         -8.8100e-04,  4.2994e-03,  1.2491e-02,  9.0585e-03, -2.0576e-02,
#          1.4201e-02,  3.2520e-02,  5.0759e-02, -3.9831e-02,  2.8746e-02,
#          1.9491e-02,  8.8553e-02,  3.0388e-02, -5.7117e-02, -1.0321e-02,
#          7.4461e-03, -4.7793e-02, -6.4483e-02, -3.1215e-02,  4.9529e-02,
#         -2.9553e-02,  6.8209e-02,  3.3187e-02, -3.2961e-02,  2.5840e-02,
#          2.7037e-02,  1.2402e-03,  6.4011e-02,  6.7227e-04,  5.2325e-02,
# ...

# %%
torch.stack(mask_embeds).flatten(start_dim=1)
# Out:
# tensor([[ 0.0268,  0.0336,  0.1473,  ...,  0.1093, -0.0062, -0.0777],
#         [ 0.0197,  0.0354,  0.1481,  ...,  0.0623, -0.0079, -0.0622],
#         [ 0.0177,  0.0398,  0.1579,  ...,  0.0484, -0.0059, -0.0966],
#         ...,
#         [ 0.0031, -0.0405,  0.0369,  ..., -0.0351, -0.0301,  0.0341],
#         [-0.0013, -0.0401,  0.0642,  ..., -0.0033, -0.0244,  0.0439],
#         [ 0.0121, -0.0300,  0.0397,  ..., -0.0271, -0.0112,  0.0346]])
